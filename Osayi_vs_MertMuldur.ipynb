# %% [markdown]
# ### Osayi Samuel ve Mert Müldür 2023/2024 performans karşılaştırması

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import glob
glob.glob("*.csv") #dosya konumunda bulunan csv uzantılı dosyaları görmeye yarayan fonksiyon
# Out:
# ['osayi.csv', 'mert_muldur.csv']

# %%
all_dfs = []
for df in glob.glob("*.csv"):
    print(f'Loading {df}')
    new_df = pd.read_csv(df)
    all_dfs.append(new_df)
#tüm veri setlerini aynı anda yüklemek için kullanılan kod
# Out:
# Loading osayi.csv
# Loading mert_muldur.csv

# %%
data = pd.concat(all_dfs)

# %%
data
# Out:
#              Full Name        Team     League  Year      Type  Age   Position  \
# 0  Bright Osayi-Samuel  Fenerbahçe  Süper Lig  2023  SEASONAL   25  Full Back
# 0          Mert Müldür  Fenerbahçe  Süper Lig  2023  SEASONAL   23  Full Back
#
#   Role  Jersey Number        SPR  ...  Counterpressing actions  \
# 0   FB             21  38.161202  ...                        6
# 0   FB             16  34.218060  ...                       11
#
#    Counterpressing actions P1000  Ground duel win %  Aerial duel win %  \
# 0                         0.9489          60.000000          53.846154
# 0                         3.0420          42.622951          85.714286
#
#    Defensive Aero  Offensive Aero  Fouls  Fouls P1000  Ball Recoveries  \
# 0            43.6            33.0     13     2.055986               63
# 0            44.2            43.9      8     2.212389               40
#
#    Ball Recoveries P1000
# 0               9.963625
# 0              11.061947
#
# [2 rows x 55 columns]

# %%
data.dropna(axis=1, inplace=True)

# %%
data.transpose()
# Out:
#                                                  0            0
# Full Name                      Bright Osayi-Samuel  Mert Müldür
# Team                                    Fenerbahçe   Fenerbahçe
# League                                   Süper Lig    Süper Lig
# Year                                          2023         2023
# Type                                      SEASONAL     SEASONAL
# Age                                             25           23
# Position                                 Full Back    Full Back
# Role                                            FB           FB
# Jersey Number                                   21           16
# SPR                                      38.161202     34.21806
# Appearances                                     13           14
# Minutes Played                                1060          620
# Goals                                            2            1
# Goals P90                                 0.169811     0.145161
# xG                                        0.589351     0.733817
# xG P90                                    0.050039     0.106522
# npxG                                      0.589351     0.733817
# npxG P90                                  0.050039     0.106522
# xGoT                                      0.793965     0.575873
# xGoT Faced                                       0            0
# SGA                                        0.28844     0.097894
# Shots                                            3            5
# Shots On Target                                  2            2
# Shot touch %                              0.468019     1.153846
# Goals prevented per xGoT                         0            0
# Assists                                          1            1
# Assists P90                               0.084906     0.145161
# xA                                        0.556358     1.091479
# xA P90                                    0.047238      0.15844
# opxA                                      0.450208     1.082152
# opxA P90                                  0.038225     0.157087
# xOVA                                      0.753087      1.43972
# xOVA P90                                  0.063941     0.208992
# xThreat                                   0.444731     0.743065
# xThreat P90                                0.03776     0.107864
# xThreat from passes                       0.174725     0.661979
# xThreat from passes P90                   0.014835     0.096094
# xThreat from carries                      0.270006     0.081086
# xThreat from carries P90                  0.022925     0.011771
# Tackles                                         26           13
# Tackles P1000                             4.111972     3.595133
# Interceptions                                   15           18
# Interceptions P1000                       2.372292     4.977876
# % xG blocked                              1.332282      0.77089
# Counterpressing actions                          6           11
# Counterpressing actions P1000               0.9489        3.042
# Ground duel win %                             60.0    42.622951
# Aerial duel win %                        53.846154    85.714286
# Defensive Aero                                43.6         44.2
# Offensive Aero                                33.0         43.9
# Fouls                                           13            8
# Fouls P1000                               2.055986     2.212389
# Ball Recoveries                                 63           40
# Ball Recoveries P1000                     9.963625    11.061947

# %% [markdown]
# •	Expected Goals (xG): quantifying shot quality by assigning goal probabilities to shots
#
# •	Expected Assists (xA): crediting creativity by assigning assist probabilities to passes
#
# •	Expected Offensive Value Added (xOVA): isolating players' offensive contribution;
#
# •	Expected Goals on Target (xGoT) / Goals prevented: measuring shooting and goalkeeping skill;
#
# •	Expected Threat (xT): Credits those actions which bring the ball closer to goal including actions before shots or key passes
#
# •	Expected Threat from Passes (xT Pass): Expected Threat generated from passes
#
# •	Expected Threat from Carries (xT Carry): Expected Threat generated from ball carries
#
# •	Expected Points (xPts): An expectation value for points gained in each match through Expected Goals models
#
# •	Gegenpressing Intensity (GPI): The fraction of times a team immediately attempts to regain the ball after losing possession in attacking areas

# %%
df_defans = data[["Full Name","Appearances","Minutes Played","Tackles","Interceptions","% xG blocked","Counterpressing actions","Ground duel win %","Aerial duel win %",]]

# %%
df_defans
# Out:
#              Full Name  Appearances  Minutes Played  Tackles  Interceptions  \
# 0  Bright Osayi-Samuel           13            1060       26             15
# 0          Mert Müldür           14             620       13             18
#
#    % xG blocked  Counterpressing actions
# 0      1.332282                        6
# 0      0.770890                       11

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0 to 0
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Full Name                      2 non-null      object
#  1   Team                           2 non-null      object
#  2   League                         2 non-null      object
#  3   Year                           2 non-null      int64
#  4   Type                           2 non-null      object
#  5   Age                            2 non-null      int64
#  6   Position                       2 non-null      object
#  7   Role                           2 non-null      object
#  8   Jersey Number                  2 non-null      int64
#  9   SPR                            2 non-null      float64
#  10  Appearances                    2 non-null      int64
#  11  Minutes Played                 2 non-null      int64
#  12  Goals                          2 non-null      int64
#  13  Goals P90                      2 non-null      float64
#  14  xG                             2 non-null      float64
#  15  xG P90                         2 non-null      float64
#  16  npxG                           2 non-null      float64
#  17  npxG P90                       2 non-null      float64
#  18  xGoT                           2 non-null      float64
#  19  xGoT Faced                     2 non-null      int64
#  20  SGA                            2 non-null      float64
#  21  Shots                          2 non-null      int64
#  22  Shots On Target                2 non-null      int64
#  23  Shot touch %                   2 non-null      float64
#  24  Goals prevented per xGoT       2 non-null      int64
#  25  Assists                        2 non-null      int64
#  26  Assists P90                    2 non-null      float64
#  27  xA                             2 non-null      float64
#  28  xA P90                         2 non-null      float64
#  29  opxA                           2 non-null      float64
#  30  opxA P90                       2 non-null      float64
#  31  xOVA                           2 non-null      float64
#  32  xOVA P90                       2 non-null      float64
#  33  xThreat                        2 non-null      float64
#  34  xThreat P90                    2 non-null      float64
#  35  xThreat from passes            2 non-null      float64
#  36  xThreat from passes P90        2 non-null      float64
#  37  xThreat from carries           2 non-null      float64
#  38  xThreat from carries P90       2 non-null      float64
#  39  Tackles                        2 non-null      int64
#  40  Tackles P1000                  2 non-null      float64
#  41  Interceptions                  2 non-null      int64
#  42  Interceptions P1000            2 non-null      float64
#  43  % xG blocked                   2 non-null      float64
#  44  Counterpressing actions        2 non-null      int64
#  45  Counterpressing actions P1000  2 non-null      float64
#  46  Ground duel win %              2 non-null      float64
#  47  Aerial duel win %              2 non-null      float64
#  48  Defensive Aero                 2 non-null      float64
#  49  Offensive Aero                 2 non-null      float64
#  50  Fouls                          2 non-null      int64
#  51  Fouls P1000                    2 non-null      float64
#  52  Ball Recoveries                2 non-null      int64
#  53  Ball Recoveries P1000          2 non-null      float64
# dtypes: float64(32), int64(16), object(6)
# memory usage: 988.0+ bytes
